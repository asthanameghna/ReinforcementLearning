# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    def __init__(self, ALPHA):
        super(DeepQNetwork, self).__init__()
        #self.conv1 = nn.Conv2d(3, 32, 8, stride=4, padding=1)
        self.conv1 = nn.Conv2d(1, 32, 8, stride=4, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
        self.conv3 = nn.Conv2d(64, 128, 3)
        #self.fc1 = nn.Linear(128*23*16, 512)
        self.fc1 = nn.Linear(128*19*8, 512)
        self.fc2 = nn.Linear(512, 6)
        self.optimizer = optim.SGD(self.parameters(), lr=ALPHA, momentum=0.9)
        #self.optimizer = optim.RMSprop(self.parameters(), lr=ALPHA)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda' if T.cuda.is_available() else 'cpu')     
        print('Using device:', self.device)
        print()
        self.to(self.device)

    def forward(self, observation):
        observation = T.Tensor(observation).to(self.device)        
        #observation = observation.view(-1, 3, 210, 160).to(self.device)        
        observation = observation.view(-1, 1, 185, 95)      
        observation = F.relu(self.conv1(observation))     
        observation = F.relu(self.conv2(observation))       
        observation = F.relu(self.conv3(observation))  
        #observation = observation.view(-1, 128*23*16).to(self.device)        
        observation = observation.view(-1, 128*19*8)    
        observation = F.relu(self.fc1(observation))  
        actions = self.fc2(observation)
        return actions

class Agent(object):
    def __init__(self, gamma, epsilon, alpha, 
                 maxMemorySize, epsEnd=0.05, 
                 replace=10000, actionSpace=[0,1,2,3,4,5]):
        self.GAMMA = gamma
        self.EPSILON = epsilon
        self.EPS_END = epsEnd
        self.ALPHA = alpha
        self.actionSpace = actionSpace
        self.memSize = maxMemorySize
        self.steps = 0
        self.learn_step_counter = 0
        self.memory = []
        self.memCntr = 0
        self.replace_target_cnt = replace
        self.Q_eval = DeepQNetwork(alpha)
        self.Q_next = DeepQNetwork(alpha)

    def storeTransition(self, state, action, reward, state_):
        if self.memCntr < self.memSize:
            self.memory.append([state, action, reward, state_])
        else:            
            self.memory[self.memCntr%self.memSize] = [state, action, reward, state_]
        self.memCntr += 1
        
    def chooseAction(self, observation):
        rand = np.random.random()
        actions = self.Q_eval.forward(observation)
        if rand < 1 - self.EPSILON:
            action = T.argmax(actions[1]).item()
        else:
            action = np.random.choice(self.actionSpace)            
        self.steps += 1
        return action
    
    def learn(self, batch_size):
        self.Q_eval.optimizer.zero_grad()
        if self.replace_target_cnt is not None and \
           self.learn_step_counter % self.replace_target_cnt == 0:
            self.Q_next.load_state_dict(self.Q_eval.state_dict())

        if self.memCntr+batch_size < self.memSize:            
            memStart = int(np.random.choice(range(self.memCntr)))
        else:
            memStart = int(np.random.choice(range(self.memSize-batch_size-1)))
        miniBatch=self.memory[memStart:memStart+batch_size]
        memory = np.array(miniBatch)

        # convert to list because memory is an array of numpy objects
        Qpred = self.Q_eval.forward(list(memory[:,0][:])).to(self.Q_eval.device)
        Qnext = self.Q_next.forward(list(memory[:,3][:])).to(self.Q_eval.device)       
        
        maxA = T.argmax(Qnext, dim=1).to(self.Q_eval.device) 
        rewards = T.Tensor(list(memory[:,2])).to(self.Q_eval.device)        
        Qtarget = Qpred        
        Qtarget[:,maxA] = rewards + self.GAMMA*T.max(Qnext[1])
        
        if self.steps > 500:
            if self.EPSILON - 1e-4 > self.EPS_END:
                self.EPSILON -= 1e-4
            else:
                self.EPSILON = self.EPS_END

        #Qpred.requires_grad_()        
        loss = self.Q_eval.loss(Qtarget, Qpred).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        self.learn_step_counter += 1

# %%
import matplotlib.pyplot as plt 
import numpy as np

def plotLearning(x, scores, epsilons, filename):   
    fig=plt.figure()
    ax=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)

    ax.plot(x, epsilons, color="C0")
    ax.set_xlabel("Game", color="C0")
    ax.set_ylabel("Epsilon", color="C0")
    ax.tick_params(axis='x', colors="C0")
    ax.tick_params(axis='y', colors="C0")

    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-5):(t+1)])

    ax2.scatter(x, running_avg, color="C1")
    #ax2.xaxis.tick_top()
    ax2.axes.get_xaxis().set_visible(False)    
    ax2.yaxis.tick_right()
    #ax2.set_xlabel('x label 2', color="C1") 
    ax2.set_ylabel('Score', color="C1")       
    #ax2.xaxis.set_label_position('top') 
    ax2.yaxis.set_label_position('right') 
    #ax2.tick_params(axis='x', colors="C1")
    ax2.tick_params(axis='y', colors="C1")

    plt.savefig(filename)

# %%
import gym
import numpy as np 
from gym import wrappers

if __name__ == '__main__':
    env = gym.make('SpaceInvaders-v0')
    brain = Agent(gamma=0.95, epsilon=1.0, 
                  alpha=0.003, maxMemorySize=5000,
                  replace=None)   
    while brain.memCntr < brain.memSize:
        observation = env.reset()
        done = False
        while not done:
            # 0 no action, 1 fire, 2 move right, 3 move left, 4 move right fire, 5 move left fire
            action = env.action_space.sample()
            observation_, reward, done, info = env.step(action)
            if done and info['ale.lives'] == 0:
                reward = -100                  
            brain.storeTransition(np.mean(observation[15:200,30:125], axis=2), action, reward, 
                                np.mean(observation_[15:200,30:125], axis=2))
            observation = observation_
    print('done initializing memory')

    scores = []
    epsHistory = []
    numGames = 250
    batch_size=32
    # uncomment the line below to record every episode. 
    # env = wrappers.Monitor(env, "tmp/space-invaders-1", video_callable=lambda episode_id: True, force=True)
    for i in range(numGames):
        print('starting game ', i+1, 'epsilon: %.4f' % brain.EPSILON)
        epsHistory.append(brain.EPSILON)        
        done = False
        observation = env.reset()
        frames = [np.sum(observation[15:200,30:125], axis=2)]
        score = 0
        lastAction = 0   
        while not done:
            if len(frames) == 3:
                action = brain.chooseAction(frames)
                frames = []
            else:
                action = lastAction
            observation_, reward, done, info = env.step(action)
            score += reward
            frames.append(np.sum(observation_[15:200,30:125], axis=2))
            if done and info['ale.lives'] == 0:
                reward = -100 
            brain.storeTransition(np.mean(observation[15:200,30:125], axis=2), action, reward, 
                                  np.mean(observation_[15:200,30:125], axis=2))
            observation = observation_            
            brain.learn(batch_size)
            lastAction = action
            #env.render()
        scores.append(score)
        print('score:',score)
    x = [i+1 for i in range(numGames)]
    fileName = str(numGames) + 'Games' + 'Gamma' + str(brain.GAMMA) + \
               'Alpha' + str(brain.ALPHA) + 'Memory' + str(brain.memSize)+ '.png'    
    plotLearning(x, scores, epsHistory, fileName)
# Out:
# Using device: cpu
#
# Using device: cpu
#
# done initializing memory
# starting game  1 epsilon: 1.0000
# score: 105.0
# starting game  2 epsilon: 1.0000
# score: 70.0
# starting game  3 epsilon: 1.0000
# score: 135.0
# starting game  4 epsilon: 0.9283
# score: 80.0
# starting game  5 epsilon: 0.8886
# score: 90.0
# starting game  6 epsilon: 0.8195
# score: 120.0
# starting game  7 epsilon: 0.7510
# score: 390.0
# starting game  8 epsilon: 0.6405
# score: 185.0
# starting game  9 epsilon: 0.5338
# score: 150.0
# starting game  10 epsilon: 0.4558
# score: 420.0
# starting game  11 epsilon: 0.3191
# score: 135.0
# starting game  12 epsilon: 0.2574
# score: 655.0
# starting game  13 epsilon: 0.1339
# score: 180.0
# starting game  14 epsilon: 0.0681
# score: 315.0
# starting game  15 epsilon: 0.0500
# score: 105.0
# starting game  16 epsilon: 0.0500
# score: 50.0
# starting game  17 epsilon: 0.0500
# score: 75.0
# starting game  18 epsilon: 0.0500
# score: 395.0
# starting game  19 epsilon: 0.0500
# score: 140.0
# starting game  20 epsilon: 0.0500
# score: 315.0
# starting game  21 epsilon: 0.0500
# score: 155.0
# starting game  22 epsilon: 0.0500
# score: 360.0
# starting game  23 epsilon: 0.0500
# score: 180.0
# starting game  24 epsilon: 0.0500
# score: 210.0
# starting game  25 epsilon: 0.0500
# score: 255.0
# starting game  26 epsilon: 0.0500
# score: 105.0
# starting game  27 epsilon: 0.0500
# score: 260.0
# starting game  28 epsilon: 0.0500
# score: 210.0
# starting game  29 epsilon: 0.0500
# score: 460.0
# starting game  30 epsilon: 0.0500
# score: 320.0
# starting game  31 epsilon: 0.0500
# score: 150.0
# starting game  32 epsilon: 0.0500
# score: 105.0
# starting game  33 epsilon: 0.0500
# score: 135.0
# starting game  34 epsilon: 0.0500
# score: 220.0
# starting game  35 epsilon: 0.0500
# score: 240.0
# starting game  36 epsilon: 0.0500
# score: 260.0
# starting game  37 epsilon: 0.0500
# score: 180.0
# starting game  38 epsilon: 0.0500
# score: 225.0
# starting game  39 epsilon: 0.0500
# score: 165.0
# starting game  40 epsilon: 0.0500
# score: 260.0
# starting game  41 epsilon: 0.0500
# score: 180.0
# starting game  42 epsilon: 0.0500
# score: 265.0
# starting game  43 epsilon: 0.0500
# score: 135.0
# starting game  44 epsilon: 0.0500
# score: 320.0
# starting game  45 epsilon: 0.0500
# score: 210.0
# starting game  46 epsilon: 0.0500
# score: 140.0
# starting game  47 epsilon: 0.0500
# score: 130.0
# starting game  48 epsilon: 0.0500
# score: 130.0
# starting game  49 epsilon: 0.0500
# score: 155.0
# starting game  50 epsilon: 0.0500
# score: 305.0
# starting game  51 epsilon: 0.0500
# score: 380.0
# starting game  52 epsilon: 0.0500
# score: 310.0
# starting game  53 epsilon: 0.0500
# score: 385.0
# starting game  54 epsilon: 0.0500
# score: 485.0
# starting game  55 epsilon: 0.0500
# score: 180.0
# starting game  56 epsilon: 0.0500
# score: 185.0
# starting game  57 epsilon: 0.0500
# score: 165.0
# starting game  58 epsilon: 0.0500
# score: 345.0
# starting game  59 epsilon: 0.0500
# score: 210.0
# starting game  60 epsilon: 0.0500
# score: 290.0
# starting game  61 epsilon: 0.0500
# score: 165.0
# starting game  62 epsilon: 0.0500
# score: 440.0
# starting game  63 epsilon: 0.0500
# score: 305.0
# starting game  64 epsilon: 0.0500
# score: 410.0
# starting game  65 epsilon: 0.0500
# score: 105.0
# starting game  66 epsilon: 0.0500
# score: 350.0
# starting game  67 epsilon: 0.0500
# score: 455.0
# starting game  68 epsilon: 0.0500
# score: 210.0
# starting game  69 epsilon: 0.0500
# score: 50.0
# starting game  70 epsilon: 0.0500
# score: 160.0
# starting game  71 epsilon: 0.0500
# score: 180.0
# starting game  72 epsilon: 0.0500
# score: 65.0
# starting game  73 epsilon: 0.0500
# score: 305.0
# starting game  74 epsilon: 0.0500
# score: 260.0
# starting game  75 epsilon: 0.0500
# score: 155.0
# starting game  76 epsilon: 0.0500
# score: 105.0
# starting game  77 epsilon: 0.0500
# score: 420.0
# starting game  78 epsilon: 0.0500
# score: 210.0
# starting game  79 epsilon: 0.0500
# score: 315.0
# starting game  80 epsilon: 0.0500
# score: 520.0
# starting game  81 epsilon: 0.0500
# score: 210.0
# starting game  82 epsilon: 0.0500
# score: 135.0
# starting game  83 epsilon: 0.0500
# score: 30.0
# starting game  84 epsilon: 0.0500
# score: 205.0
# starting game  85 epsilon: 0.0500
# score: 105.0
# starting game  86 epsilon: 0.0500
# score: 135.0
# starting game  87 epsilon: 0.0500
# score: 135.0
# starting game  88 epsilon: 0.0500
# score: 260.0
# starting game  89 epsilon: 0.0500
# score: 220.0
# starting game  90 epsilon: 0.0500
# score: 300.0
# starting game  91 epsilon: 0.0500
# score: 210.0
# starting game  92 epsilon: 0.0500
# score: 120.0
# starting game  93 epsilon: 0.0500
# score: 455.0
# starting game  94 epsilon: 0.0500
# score: 450.0
# starting game  95 epsilon: 0.0500
# score: 215.0
# starting game  96 epsilon: 0.0500
# score: 310.0
# starting game  97 epsilon: 0.0500
# score: 120.0
# starting game  98 epsilon: 0.0500
# score: 155.0
# starting game  99 epsilon: 0.0500
# score: 220.0
# starting game  100 epsilon: 0.0500
# score: 760.0
# starting game  101 epsilon: 0.0500
# score: 485.0
# starting game  102 epsilon: 0.0500
# score: 75.0
# starting game  103 epsilon: 0.0500
# score: 540.0
# starting game  104 epsilon: 0.0500
# score: 515.0
# starting game  105 epsilon: 0.0500
# score: 135.0
# starting game  106 epsilon: 0.0500
# score: 260.0
# starting game  107 epsilon: 0.0500
# score: 315.0
# starting game  108 epsilon: 0.0500
# score: 165.0
# starting game  109 epsilon: 0.0500
# score: 515.0
# starting game  110 epsilon: 0.0500
# score: 105.0
# starting game  111 epsilon: 0.0500
# score: 645.0
# starting game  112 epsilon: 0.0500
# score: 410.0
# starting game  113 epsilon: 0.0500
# score: 350.0
# starting game  114 epsilon: 0.0500
# score: 105.0
# starting game  115 epsilon: 0.0500
# score: 155.0
# starting game  116 epsilon: 0.0500
# score: 520.0
# starting game  117 epsilon: 0.0500
# score: 30.0
# starting game  118 epsilon: 0.0500
# score: 210.0
# starting game  119 epsilon: 0.0500
# score: 105.0
# starting game  120 epsilon: 0.0500
# score: 120.0
# starting game  121 epsilon: 0.0500
# score: 120.0
# starting game  122 epsilon: 0.0500
# score: 475.0
# starting game  123 epsilon: 0.0500
# score: 205.0
# starting game  124 epsilon: 0.0500
# score: 285.0
# starting game  125 epsilon: 0.0500
# score: 410.0
# starting game  126 epsilon: 0.0500
# score: 150.0
# starting game  127 epsilon: 0.0500
# score: 405.0
# starting game  128 epsilon: 0.0500
# score: 355.0
# starting game  129 epsilon: 0.0500
# score: 490.0
# starting game  130 epsilon: 0.0500
# score: 130.0
# starting game  131 epsilon: 0.0500
# score: 120.0
# starting game  132 epsilon: 0.0500
# score: 105.0
# starting game  133 epsilon: 0.0500
# score: 210.0
# starting game  134 epsilon: 0.0500
# score: 210.0
# starting game  135 epsilon: 0.0500
# score: 110.0
# starting game  136 epsilon: 0.0500
# score: 320.0
# starting game  137 epsilon: 0.0500
# score: 155.0
# starting game  138 epsilon: 0.0500
# score: 105.0
# starting game  139 epsilon: 0.0500
# score: 305.0
# starting game  140 epsilon: 0.0500
# score: 155.0
# starting game  141 epsilon: 0.0500
# score: 105.0
# starting game  142 epsilon: 0.0500
# score: 105.0
# starting game  143 epsilon: 0.0500
# score: 210.0
# starting game  144 epsilon: 0.0500
# score: 225.0
# starting game  145 epsilon: 0.0500
# score: 200.0
# starting game  146 epsilon: 0.0500
# score: 180.0
# starting game  147 epsilon: 0.0500
# score: 210.0
# starting game  148 epsilon: 0.0500
# score: 210.0
# starting game  149 epsilon: 0.0500
# score: 365.0
# starting game  150 epsilon: 0.0500
# score: 175.0
# starting game  151 epsilon: 0.0500
# score: 285.0
# starting game  152 epsilon: 0.0500
# score: 155.0
# starting game  153 epsilon: 0.0500
# score: 340.0
# starting game  154 epsilon: 0.0500
# score: 445.0
# starting game  155 epsilon: 0.0500
# score: 365.0
# starting game  156 epsilon: 0.0500
# score: 210.0
# starting game  157 epsilon: 0.0500
# score: 165.0
# starting game  158 epsilon: 0.0500
# score: 105.0
# starting game  159 epsilon: 0.0500
# score: 210.0
# starting game  160 epsilon: 0.0500
# score: 180.0
# starting game  161 epsilon: 0.0500
# score: 105.0
# starting game  162 epsilon: 0.0500
# score: 135.0
# starting game  163 epsilon: 0.0500
# score: 135.0
# starting game  164 epsilon: 0.0500
# score: 135.0
# starting game  165 epsilon: 0.0500
# score: 365.0
# starting game  166 epsilon: 0.0500
# score: 575.0
# starting game  167 epsilon: 0.0500
# score: 105.0
# starting game  168 epsilon: 0.0500
# score: 260.0
# starting game  169 epsilon: 0.0500
# score: 155.0
# starting game  170 epsilon: 0.0500
# score: 120.0
# starting game  171 epsilon: 0.0500
# score: 215.0
# starting game  172 epsilon: 0.0500
# score: 105.0
# starting game  173 epsilon: 0.0500
# score: 105.0
# starting game  174 epsilon: 0.0500
# score: 390.0
# starting game  175 epsilon: 0.0500
# score: 75.0
# starting game  176 epsilon: 0.0500
# score: 290.0
# starting game  177 epsilon: 0.0500
# score: 105.0
# starting game  178 epsilon: 0.0500
# score: 540.0
# starting game  179 epsilon: 0.0500
# score: 155.0
# starting game  180 epsilon: 0.0500
# score: 155.0
# starting game  181 epsilon: 0.0500
# score: 215.0
# starting game  182 epsilon: 0.0500
# score: 155.0
# starting game  183 epsilon: 0.0500
# score: 155.0
# starting game  184 epsilon: 0.0500
# score: 180.0
# starting game  185 epsilon: 0.0500
# score: 255.0
# starting game  186 epsilon: 0.0500
# score: 295.0
# starting game  187 epsilon: 0.0500
# score: 460.0
# starting game  188 epsilon: 0.0500
# score: 285.0
# starting game  189 epsilon: 0.0500
# score: 105.0
# starting game  190 epsilon: 0.0500
# score: 120.0
# starting game  191 epsilon: 0.0500
# score: 105.0
# starting game  192 epsilon: 0.0500
# score: 120.0
# starting game  193 epsilon: 0.0500
# score: 365.0
# starting game  194 epsilon: 0.0500
# score: 335.0
# starting game  195 epsilon: 0.0500
# score: 120.0
# starting game  196 epsilon: 0.0500
# score: 50.0
# starting game  197 epsilon: 0.0500
# score: 380.0
# starting game  198 epsilon: 0.0500
# score: 215.0
# starting game  199 epsilon: 0.0500
# score: 310.0
# starting game  200 epsilon: 0.0500
# score: 345.0
# starting game  201 epsilon: 0.0500
# score: 335.0
# starting game  202 epsilon: 0.0500
# score: 105.0
# starting game  203 epsilon: 0.0500
# score: 370.0
# starting game  204 epsilon: 0.0500
# score: 75.0
# starting game  205 epsilon: 0.0500
# score: 190.0
# starting game  206 epsilon: 0.0500
# score: 155.0
# starting game  207 epsilon: 0.0500
# score: 195.0
# starting game  208 epsilon: 0.0500
# score: 345.0
# starting game  209 epsilon: 0.0500
# score: 105.0
# starting game  210 epsilon: 0.0500
# score: 210.0
# starting game  211 epsilon: 0.0500
# score: 405.0
# starting game  212 epsilon: 0.0500
# score: 110.0
# starting game  213 epsilon: 0.0500
# score: 335.0
# starting game  214 epsilon: 0.0500
# score: 425.0
# starting game  215 epsilon: 0.0500
# score: 145.0
# starting game  216 epsilon: 0.0500
# score: 105.0
# starting game  217 epsilon: 0.0500
# score: 105.0
# starting game  218 epsilon: 0.0500
# score: 340.0
# starting game  219 epsilon: 0.0500
# score: 225.0
# starting game  220 epsilon: 0.0500
# score: 105.0
# starting game  221 epsilon: 0.0500
# score: 105.0
# starting game  222 epsilon: 0.0500
# score: 260.0
# starting game  223 epsilon: 0.0500
# score: 105.0
# starting game  224 epsilon: 0.0500
# score: 380.0
# starting game  225 epsilon: 0.0500
# score: 210.0
# starting game  226 epsilon: 0.0500
# score: 215.0
# starting game  227 epsilon: 0.0500
# score: 160.0
# starting game  228 epsilon: 0.0500
# score: 50.0
# starting game  229 epsilon: 0.0500
# score: 240.0
# starting game  230 epsilon: 0.0500
# score: 460.0
# starting game  231 epsilon: 0.0500
# score: 225.0
# starting game  232 epsilon: 0.0500
# score: 210.0
# starting game  233 epsilon: 0.0500
# score: 270.0
# starting game  234 epsilon: 0.0500
# score: 315.0
# starting game  235 epsilon: 0.0500
# score: 210.0
# starting game  236 epsilon: 0.0500
# score: 485.0
# starting game  237 epsilon: 0.0500
# score: 110.0
# starting game  238 epsilon: 0.0500
# score: 120.0
# starting game  239 epsilon: 0.0500
# score: 210.0
# starting game  240 epsilon: 0.0500
# score: 210.0
# starting game  241 epsilon: 0.0500
# score: 210.0
# starting game  242 epsilon: 0.0500
# score: 485.0
# starting game  243 epsilon: 0.0500
# score: 105.0
# starting game  244 epsilon: 0.0500
# score: 120.0
# starting game  245 epsilon: 0.0500
# score: 110.0
# starting game  246 epsilon: 0.0500
# score: 105.0
# starting game  247 epsilon: 0.0500
# score: 155.0
# starting game  248 epsilon: 0.0500
# score: 380.0
# starting game  249 epsilon: 0.0500
# score: 240.0
# starting game  250 epsilon: 0.0500
# score: 285.0

# %%
for i in range(1):
    print('starting game ', i+1, 'epsilon: %.4f' % brain.EPSILON)
#     epsHistory.append(brain.EPSILON)        
    done = False
    observation = env.reset()
    frames = [np.sum(observation[15:200,30:125], axis=2)]
    score = 0
    lastAction = 0   
    while not done:
        if len(frames) == 3:
            action = brain.chooseAction(frames)
            frames = []
        else:
            action = lastAction
        observation_, reward, done, info = env.step(action)
        score += reward
        frames.append(np.sum(observation_[15:200,30:125], axis=2))
        if done and info['ale.lives'] == 0:
            reward = -100 
        brain.storeTransition(np.mean(observation[15:200,30:125], axis=2), action, reward, 
                                np.mean(observation_[15:200,30:125], axis=2))
        observation = observation_            
        brain.learn(batch_size)
        lastAction = action
        env.render()
    scores.append(score)
    print('score:',score)
# Out:
# starting game  1 epsilon: 0.0500
# score: 290.0

# %%
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # take a random action
